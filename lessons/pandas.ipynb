# %% [markdown]
# # **Pandas**

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/data_01.csv", index_col=0)

# %% [markdown]
# ### **Análise Exploratória**

# %%
df.head()
# Out:
#             age  gender             major  study_hours_per_day  \
# student_id
# 100000       26    Male  Computer Science             7.645367
# 100001       28    Male              Arts             5.700000
# 100002       17    Male              Arts             2.400000
# 100003       27   Other        Psychology             3.400000
# 100004       25  Female          Business             4.700000
#
#             social_media_hours  netflix_hours part_time_job  \
# student_id
# 100000                     3.0            0.1           Yes
# 100001                     0.5            0.4            No
# 100002                     4.2            0.7            No
# 100003                     4.6            2.3           Yes
# 100004                     0.8            2.7           Yes
#
#             attendance_percentage  sleep_hours diet_quality  ...  screen_time  \
# student_id                                                   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80000 entries, 100000 to 179999
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            80000 non-null  int64
#  1   gender                         80000 non-null  object
#  2   major                          80000 non-null  object
#  3   study_hours_per_day            80000 non-null  float64
#  4   social_media_hours             80000 non-null  float64
#  5   netflix_hours                  80000 non-null  float64
#  6   part_time_job                  80000 non-null  object
#  7   attendance_percentage          80000 non-null  float64
#  8   sleep_hours                    80000 non-null  float64
#  9   diet_quality                   80000 non-null  object
#  10  exercise_frequency             80000 non-null  int64
#  11  parental_education_level       80000 non-null  object
# ...

# %%
df.shape
# Out:
# (80000, 30)

# %%
df.describe()
# Out:
#                 age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  80000.000000         80000.000000        80000.000000   80000.000000
# mean      22.004288             4.174388            2.501366       1.997754
# std        3.745570             2.004135            1.445441       1.155992
# min       16.000000             0.000000            0.000000       0.000000
# 25%       19.000000             2.800000            1.200000       1.000000
# 50%       22.000000             4.125624            2.500000       2.000000
# 75%       25.000000             5.500000            3.800000       3.000000
# max       28.000000            12.000000            5.000000       4.000000
#
#        attendance_percentage   sleep_hours  exercise_frequency  \
# count           80000.000000  80000.000000        80000.000000
# mean               69.967884      7.017417            3.516587
# std                17.333015      1.467377            2.291575
# ...

# %% [markdown]
# ### **Classificação de Dados**

# %%
df.sort_values("exam_score", ascending=False).head()
# Out:
#             age  gender             major  study_hours_per_day  \
# student_id
# 179983       23   Other              Arts             5.400000
# 179979       26    Male           Biology             7.400000
# 179977       16   Other              Arts             3.100000
# 179974       17   Other              Arts             3.000000
# 179971       23  Female  Computer Science             6.475817
#
#             social_media_hours  netflix_hours part_time_job  \
# student_id
# 179983                     1.6            0.6           Yes
# 179979                     1.7            0.9            No
# 179977                     4.8            1.3            No
# 179974                     3.2            0.8            No
# 179971                     3.7            3.2            No
#
#             attendance_percentage  sleep_hours diet_quality  ...  screen_time  \
# student_id                                                   ...
# ...

# %%
df.sort_values(["study_hours_per_day", "exam_score"], ascending=False).head()
# Out:
#             age  gender             major  study_hours_per_day  \
# student_id
# 137547       23   Other  Computer Science                 12.0
# 142053       18  Female          Business                 12.0
# 133186       20    Male  Computer Science                 12.0
# 169160       20    Male  Computer Science                 12.0
# 160538       27    Male        Psychology                 11.9
#
#             social_media_hours  netflix_hours part_time_job  \
# student_id
# 137547                     1.3            1.1           Yes
# 142053                     1.1            3.8            No
# 133186                     1.8            2.4            No
# 169160                     3.7            1.0           Yes
# 160538                     4.8            2.6            No
#
#             attendance_percentage  sleep_hours diet_quality  ...  screen_time  \
# student_id                                                   ...
# ...

# %% [markdown]
# ### **Filtragem de Dados**

# %%
df[["study_hours_per_day", "exam_score"]].head()
# Out:
#             study_hours_per_day  exam_score
# student_id
# 100000                 7.645367         100
# 100001                 5.700000          99
# 100002                 2.400000          98
# 100003                 3.400000         100
# 100004                 4.700000          98
