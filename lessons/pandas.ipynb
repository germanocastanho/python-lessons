# %% [markdown]
# # **Pandas**

# %% [markdown]
# ### **Series**

# %%
import pandas as pd
import numpy as np

# %%
data = {"0": "A", "1": "B", "2": "C", "3": "D", "4": "E"}

pd.Series(data)
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# dtype: object

# %% [markdown]
# ### **DataFrame**

# %%
df = pd.DataFrame(
    data=np.random.randn(5, 3),
    index=["A", "B", "C", "D", "E"],
    columns=["X", "Y", "Z"],
)

# %%
df
# Out:
#           X         Y         Z
# A  0.004635  0.114983  1.137850
# B -0.559709 -1.458544  0.370966
# C -2.074534  0.494318 -0.789391
# D -1.457408  0.483878  0.745536
# E -0.745443  0.932508  0.364982
